# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv("./data/train.csv")
test = pd.read_csv("./data/test.csv")

# %% [markdown]
# ## Data Exploration

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     588 non-null    object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
train['Alley'].value_counts()
# Out:
# Alley
# Grvl    50
# Pave    41
# Name: count, dtype: int64

# %% [markdown]
# We need to change the alley's NA as another category

# %%
numeric = [ var for var in train.columns if train[var].dtype == 'int64']
numeric
# Out:
# ['Id',
#  'MSSubClass',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SalePrice']

# %%
non_numeric = ["MSSubClass","OverallQual","OverallCond","YearBuilt","YearRemodAdd","MoSold","YrSold"]
numeric = list(set(numeric) - set(non_numeric))
numeric
# Out:
# ['LotArea',
#  'MiscVal',
#  'BsmtUnfSF',
#  'Id',
#  'PoolArea',
#  'OpenPorchSF',
#  'ScreenPorch',
#  'TotalBsmtSF',
#  'GrLivArea',
#  '1stFlrSF',
#  'Fireplaces',
#  'GarageCars',
#  'EnclosedPorch',
#  'BsmtHalfBath',
#  'BsmtFullBath',
#  'GarageArea',
#  '3SsnPorch',
#  'BsmtFinSF1',
#  'BedroomAbvGr',
#  'FullBath',
#  'SalePrice',
#  'HalfBath',
#  'LowQualFinSF',
#  '2ndFlrSF',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'WoodDeckSF',
#  'BsmtFinSF2']

# %%
train[numeric].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 28 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   LotArea        1460 non-null   int64
#  1   MiscVal        1460 non-null   int64
#  2   BsmtUnfSF      1460 non-null   int64
#  3   Id             1460 non-null   int64
#  4   PoolArea       1460 non-null   int64
#  5   OpenPorchSF    1460 non-null   int64
#  6   ScreenPorch    1460 non-null   int64
#  7   TotalBsmtSF    1460 non-null   int64
#  8   GrLivArea      1460 non-null   int64
#  9   1stFlrSF       1460 non-null   int64
#  10  Fireplaces     1460 non-null   int64
#  11  GarageCars     1460 non-null   int64
#  12  EnclosedPorch  1460 non-null   int64
#  13  BsmtHalfBath   1460 non-null   int64
#  14  BsmtFullBath   1460 non-null   int64
#  15  GarageArea     1460 non-null   int64
#  16  3SsnPorch      1460 non-null   int64
#  17  BsmtFinSF1     1460 non-null   int64
#  18  BedroomAbvGr   1460 non-null   int64
#  19  FullBath       1460 non-null   int64
#  20  SalePrice      1460 non-null   int64
#  21  HalfBath       1460 non-null   int64
#  22  LowQualFinSF   1460 non-null   int64
#  23  2ndFlrSF       1460 non-null   int64
#  24  KitchenAbvGr   1460 non-null   int64
#  25  TotRmsAbvGrd   1460 non-null   int64
#  26  WoodDeckSF     1460 non-null   int64
#  27  BsmtFinSF2     1460 non-null   int64
# dtypes: int64(28)
# memory usage: 319.5 KB

# %%
train[numeric].describe()
# Out:
#              LotArea       MiscVal    BsmtUnfSF           Id     PoolArea  \
# count    1460.000000   1460.000000  1460.000000  1460.000000  1460.000000
# mean    10516.828082     43.489041   567.240411   730.500000     2.758904
# std      9981.264932    496.123024   441.866955   421.610009    40.177307
# min      1300.000000      0.000000     0.000000     1.000000     0.000000
# 25%      7553.500000      0.000000   223.000000   365.750000     0.000000
# 50%      9478.500000      0.000000   477.500000   730.500000     0.000000
# 75%     11601.500000      0.000000   808.000000  1095.250000     0.000000
# max    215245.000000  15500.000000  2336.000000  1460.000000   738.000000
#
#        OpenPorchSF  ScreenPorch  TotalBsmtSF    GrLivArea     1stFlrSF  ...  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000  ...
# mean     46.660274    15.060959  1057.429452  1515.463699  1162.626712  ...
# std      66.256028    55.757415   438.705324   525.480383   386.587738  ...
# min       0.000000     0.000000     0.000000   334.000000   334.000000  ...
# 25%       0.000000     0.000000   795.750000  1129.500000   882.000000  ...
# 50%      25.000000     0.000000   991.500000  1464.000000  1087.000000  ...
# 75%      68.000000     0.000000  1298.250000  1776.750000  1391.250000  ...
# max     547.000000   480.000000  6110.000000  5642.000000  4692.000000  ...
#
#        BedroomAbvGr     FullBath      SalePrice     HalfBath  LowQualFinSF  \
# count   1460.000000  1460.000000    1460.000000  1460.000000   1460.000000
# mean       2.866438     1.565068  180921.195890     0.382877      5.844521
# std        0.815778     0.550916   79442.502883     0.502885     48.623081
# min        0.000000     0.000000   34900.000000     0.000000      0.000000
# 25%        2.000000     1.000000  129975.000000     0.000000      0.000000
# 50%        3.000000     2.000000  163000.000000     0.000000      0.000000
# 75%        3.000000     2.000000  214000.000000     1.000000      0.000000
# max        8.000000     3.000000  755000.000000     2.000000    572.000000
#
#           2ndFlrSF  KitchenAbvGr  TotRmsAbvGrd   WoodDeckSF   BsmtFinSF2
# count  1460.000000   1460.000000   1460.000000  1460.000000  1460.000000
# mean    346.992466      1.046575      6.517808    94.244521    46.549315
# std     436.528436      0.220338      1.625393   125.338794   161.319273
# min       0.000000      0.000000      2.000000     0.000000     0.000000
# 25%       0.000000      1.000000      5.000000     0.000000     0.000000
# 50%       0.000000      1.000000      6.000000     0.000000     0.000000
# 75%     728.000000      1.000000      7.000000   168.000000     0.000000
# max    2065.000000      3.000000     14.000000   857.000000  1474.000000
#
# [8 rows x 28 columns]

# %%
import matplotlib.pyplot as plt

# %%
train[numeric[:5]].hist(bins=50,figsize=(12,8))
plt.show()

# %% [markdown]
# GarageCars, BsmtFullBath, FullBath - could be an categorical attribute

# %%
train[numeric[5:12]].hist(bins=50,figsize=(12,8))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# There are various attributes which signifies numerical attributes but values are so limited that they could be categories. Let's call them num_Categories

# %%
num_Categories = ["FullBath","GarageCars","BsmtHalfBath","BsmtFullBath","KitchenAbvGr","Fireplaces"]

# %%
train[numeric[12:20]].hist(bins=50,figsize=(12,8))
plt.show()

# %%
train["PoolArea"].value_counts()
# Out:
# PoolArea
# 0      1453
# 512       1
# 648       1
# 576       1
# 555       1
# 480       1
# 519       1
# 738       1
# Name: count, dtype: int64

# %%
train["LowQualFinSF"].value_counts()
# Out:
# LowQualFinSF
# 0      1434
# 80        3
# 360       2
# 205       1
# 479       1
# 397       1
# 514       1
# 120       1
# 481       1
# 232       1
# 53        1
# 515       1
# 156       1
# 473       1
# 420       1
# 390       1
# 371       1
# 392       1
# 144       1
# 572       1
# 528       1
# 234       1
# 513       1
# 384       1
# Name: count, dtype: int64

# %%
num_Categories.append("TotRmsAbvGrd")
num_Categories.append("HalfBath")
num_Categories
# Out:
# ['FullBath',
#  'GarageCars',
#  'BsmtHalfBath',
#  'BsmtFullBath',
#  'KitchenAbvGr',
#  'Fireplaces',
#  'TotRmsAbvGrd',
#  'HalfBath']

# %%
train["ScreenPorch"].value_counts()
# Out:
# ScreenPorch
# 0      1344
# 192       6
# 120       5
# 224       5
# 189       4
#        ...
# 291       1
# 260       1
# 385       1
# 156       1
# 40        1
# Name: count, Length: 76, dtype: int64

# %%
train["MiscVal"].value_counts()
# Out:
# MiscVal
# 0        1408
# 400        11
# 500         8
# 700         5
# 450         4
# 600         4
# 2000        4
# 1200        2
# 480         2
# 15500       1
# 800         1
# 350         1
# 3500        1
# 1300        1
# 54          1
# 620         1
# 560         1
# 1400        1
# 8300        1
# 1150        1
# 2500        1
# Name: count, dtype: int64

# %%
len(numeric)
# Out:
# 28

# %%
train[numeric[20:28]].hist(bins=50,figsize=(12,8))
plt.show()

# %%
num_Categories.append("BedroomAbvGr")

# %%
numeric = list(set(numeric) - set(num_Categories))
numeric
# Out:
# ['LotArea',
#  'MiscVal',
#  'BsmtUnfSF',
#  'Id',
#  'PoolArea',
#  'OpenPorchSF',
#  'ScreenPorch',
#  'TotalBsmtSF',
#  'GrLivArea',
#  '1stFlrSF',
#  'EnclosedPorch',
#  'GarageArea',
#  '3SsnPorch',
#  'BsmtFinSF1',
#  'SalePrice',
#  'LowQualFinSF',
#  '2ndFlrSF',
#  'WoodDeckSF',
#  'BsmtFinSF2']

# %%
float_var = [ var for var in train.columns if train[var].dtype == "float64"]
float_var
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %%
non_numeric.append(float_var[-1])
numeric = numeric + float_var[:-1]
print(non_numeric)
print(numeric)
# Out:
# ['MSSubClass', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MoSold', 'YrSold', 'GarageYrBlt']
# ['LotArea', 'MiscVal', 'BsmtUnfSF', 'Id', 'PoolArea', 'OpenPorchSF', 'ScreenPorch', 'TotalBsmtSF', 'GrLivArea', '1stFlrSF', 'EnclosedPorch', 'GarageArea', '3SsnPorch', 'BsmtFinSF1', 'SalePrice', 'LowQualFinSF', '2ndFlrSF', 'WoodDeckSF', 'BsmtFinSF2', 'LotFrontage', 'MasVnrArea']

# %%
numeric = list(set(numeric) - set(num_Categories))
numeric
# Out:
# ['LotArea',
#  'MiscVal',
#  'BsmtUnfSF',
#  'Id',
#  'PoolArea',
#  'LotFrontage',
#  'OpenPorchSF',
#  'ScreenPorch',
#  'TotalBsmtSF',
#  'GrLivArea',
#  'MasVnrArea',
#  '1stFlrSF',
#  'EnclosedPorch',
#  'GarageArea',
#  '3SsnPorch',
#  'BsmtFinSF1',
#  'SalePrice',
#  'LowQualFinSF',
#  '2ndFlrSF',
#  'WoodDeckSF',
#  'BsmtFinSF2']

# %% [markdown]
# Numeric Attributes are separated successfully. Object types are to be looked into now.

# %%
object_var = [ var for var in train.columns if train[var].dtype =="O"]
object_var
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
train["Street"].value_counts()
# Out:
# Street
# Pave    1454
# Grvl       6
# Name: count, dtype: int64

# %%
non_numeric
# Out:
# ['MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MoSold',
#  'YrSold',
#  'GarageYrBlt']

# %%
object_var.append("MSSubClass")
object_var.append("OverallQual")
object_var.append("OverallCond")
object_var
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition',
#  'MSSubClass',
#  'OverallQual',
#  'OverallCond']

# %%
date_var = list(set(non_numeric) - set(object_var))
date_var
# Out:
# ['YearRemodAdd', 'YrSold', 'GarageYrBlt', 'MoSold', 'YearBuilt']

# %%
train.shape
# Out:
# (1460, 81)

# %%
all_var = date_var + numeric + object_var + num_Categories
all_var
# Out:
# ['YearRemodAdd',
#  'YrSold',
#  'GarageYrBlt',
#  'MoSold',
#  'YearBuilt',
#  'LotArea',
#  'MiscVal',
#  'BsmtUnfSF',
#  'Id',
#  'PoolArea',
#  'LotFrontage',
#  'OpenPorchSF',
#  'ScreenPorch',
#  'TotalBsmtSF',
#  'GrLivArea',
#  'MasVnrArea',
#  '1stFlrSF',
#  'EnclosedPorch',
#  'GarageArea',
#  '3SsnPorch',
#  'BsmtFinSF1',
#  'SalePrice',
#  'LowQualFinSF',
#  '2ndFlrSF',
#  'WoodDeckSF',
#  'BsmtFinSF2',
#  'MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition',
#  'MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'FullBath',
#  'GarageCars',
#  'BsmtHalfBath',
#  'BsmtFullBath',
#  'KitchenAbvGr',
#  'Fireplaces',
#  'TotRmsAbvGrd',
#  'HalfBath',
#  'BedroomAbvGr']

# %%
len(all_var)
# Out:
# 81

# %% [markdown]
# Given 81 attributes are divided into 3 categories: date objects, numeric objects and categories.
# - numeric,
# - object_var and num_categories for categorical
# - date_var

# %% [markdown]
# ## Data Preprocessing

# %%
train[numeric].isnull().sum()
# Out:
# LotArea            0
# MiscVal            0
# BsmtUnfSF          0
# Id                 0
# PoolArea           0
# LotFrontage      259
# OpenPorchSF        0
# ScreenPorch        0
# TotalBsmtSF        0
# GrLivArea          0
# MasVnrArea         8
# 1stFlrSF           0
# EnclosedPorch      0
# GarageArea         0
# 3SsnPorch          0
# BsmtFinSF1         0
# SalePrice          0
# LowQualFinSF       0
# 2ndFlrSF           0
# WoodDeckSF         0
# BsmtFinSF2         0
# dtype: int64

# %%
train[numeric].head(50)
# Out:
#     LotArea  MiscVal  BsmtUnfSF  Id  PoolArea  LotFrontage  OpenPorchSF  \
# 0      8450        0        150   1         0         65.0           61
# 1      9600        0        284   2         0         80.0            0
# 2     11250        0        434   3         0         68.0           42
# 3      9550        0        540   4         0         60.0           35
# 4     14260        0        490   5         0         84.0           84
# 5     14115      700         64   6         0         85.0           30
# 6     10084        0        317   7         0         75.0           57
# 7     10382      350        216   8         0          NaN          204
# 8      6120        0        952   9         0         51.0            0
# 9      7420        0        140  10         0         50.0            4
# 10    11200        0        134  11         0         70.0            0
# 11    11924        0        177  12         0         85.0           21
# 12    12968        0        175  13         0          NaN            0
# 13    10652        0       1494  14         0         91.0           33
# 14    10920        0        520  15         0          NaN          213
# 15     6120        0        832  16         0         51.0          112
# 16    11241      700        426  17         0          NaN            0
# 17    10791      500          0  18         0         72.0            0
# 18    13695        0        468  19         0         66.0          102
# 19     7560        0        525  20         0         70.0            0
# 20    14215        0       1158  21         0        101.0          154
# 21     7449        0        637  22         0         57.0            0
# 22     9742        0       1777  23         0         75.0          159
# 23     4224        0        200  24         0         44.0          110
# 24     8246        0        204  25         0          NaN           90
# 25    14230        0       1566  26         0        110.0           56
# 26     7200        0        180  27         0         60.0           32
# 27    11478        0        486  28         0         98.0           50
# 28    16321        0        207  29         0         47.0          258
# 29     6324        0        520  30         0         60.0            0
# 30     8500        0        649  31         0         50.0           54
# 31     8544        0       1228  32         0          NaN           65
# 32    11049        0       1234  33         0         85.0           30
# 33    10552        0        380  34         0         70.0           38
# 34     7313        0        408  35         0         60.0           47
# 35    13418        0       1117  36         0        108.0           32
# 36    10859        0       1097  37         0        112.0           64
# 37     8532        0         84  38         0         74.0            0
# 38     7922        0        326  39         0         68.0           52
# 39     6040        0          0  40         0         65.0            0
# 40     8658        0        445  41         0         84.0          138
# 41    16905        0        383  42         0        115.0          104
# 42     9180        0          0  43         0          NaN            0
# 43     9200        0        167  44         0          NaN            0
# 44     7945        0        465  45         0         70.0            0
# 45     7658        0       1296  46         0         61.0           82
# 46    12822        0         83  47         0         48.0           43
# 47    11096        0       1632  48         0         84.0          146
# 48     4456        0        736  49         0         33.0            0
# 49     7742        0        192  50         0         66.0            0
#
#     ScreenPorch  TotalBsmtSF  GrLivArea  ...  1stFlrSF  EnclosedPorch  \
# 0             0          856       1710  ...       856              0
# 1             0         1262       1262  ...      1262              0
# 2             0          920       1786  ...       920              0
# 3             0          756       1717  ...       961            272
# 4             0         1145       2198  ...      1145              0
# 5             0          796       1362  ...       796              0
# 6             0         1686       1694  ...      1694              0
# 7             0         1107       2090  ...      1107            228
# 8             0          952       1774  ...      1022            205
# 9             0          991       1077  ...      1077              0
# 10            0         1040       1040  ...      1040              0
# 11            0         1175       2324  ...      1182              0
# 12          176          912        912  ...       912              0
# 13            0         1494       1494  ...      1494              0
# 14            0         1253       1253  ...      1253            176
# 15            0          832        854  ...       854              0
# 16            0         1004       1004  ...      1004              0
# 17            0            0       1296  ...      1296              0
# 18            0         1114       1114  ...      1114              0
# 19            0         1029       1339  ...      1339              0
# 20            0         1158       2376  ...      1158              0
# 21            0          637       1108  ...      1108            205
# 22            0         1777       1795  ...      1795              0
# 23            0         1040       1060  ...      1060              0
# 24            0         1060       1060  ...      1060              0
# 25            0         1566       1600  ...      1600              0
# 26            0          900        900  ...       900              0
# 27            0         1704       1704  ...      1704              0
# 28            0         1484       1600  ...      1600              0
# 29            0          520        520  ...       520             87
# 30            0          649       1317  ...       649            172
# 31            0         1228       1228  ...      1228              0
# 32            0         1234       1234  ...      1234              0
# 33            0         1398       1700  ...      1700              0
# 34            0         1561       1561  ...      1561              0
# 35            0         1117       2452  ...      1132              0
# 36            0         1097       1097  ...      1097              0
# 37            0         1297       1297  ...      1297              0
# 38            0         1057       1057  ...      1057              0
# 39            0            0       1152  ...      1152              0
# 40            0         1088       1324  ...      1324              0
# 41            0         1350       1328  ...      1328              0
# 42            0          840        884  ...       884              0
# 43            0          938        938  ...       938              0
# 44            0         1150       1150  ...      1150              0
# 45            0         1752       1752  ...      1752              0
# 46          198         1434       2149  ...      1518              0
# 47            0         1656       1656  ...      1656              0
# 48            0          736       1452  ...       736            102
# 49            0          955        955  ...       955              0
#
#     GarageArea  3SsnPorch  BsmtFinSF1  SalePrice  LowQualFinSF  2ndFlrSF  \
# 0          548          0         706     208500             0       854
# 1          460          0         978     181500             0         0
# 2          608          0         486     223500             0       866
# 3          642          0         216     140000             0       756
# 4          836          0         655     250000             0      1053
# 5          480        320         732     143000             0       566
# 6          636          0        1369     307000             0         0
# 7          484          0         859     200000             0       983
# 8          468          0           0     129900             0       752
# 9          205          0         851     118000             0         0
# 10         384          0         906     129500             0         0
# 11         736          0         998     345000             0      1142
# 12         352          0         737     144000             0         0
# 13         840          0           0     279500             0         0
# 14         352          0         733     157000             0         0
# 15         576          0           0     132000             0         0
# 16         480          0         578     149000             0         0
# 17         516          0           0      90000             0         0
# 18         576          0         646     159000             0         0
# 19         294          0         504     139000             0         0
# 20         853          0           0     325300             0      1218
# 21         280          0           0     139400             0         0
# 22         534          0           0     230000             0         0
# 23         572          0         840     129900             0         0
# 24         270          0         188     154000             0         0
# 25         890          0           0     256300             0         0
# 26         576          0         234     134800             0         0
# 27         772          0        1218     306000             0         0
# 28         319          0        1277     207500             0         0
# 29         240          0           0      68500             0         0
# 30         250          0           0      40000             0       668
# 31         271          0           0     149350             0         0
# 32         484          0           0     179900             0         0
# 33         447          0        1018     165500             0         0
# 34         556          0        1153     277500             0         0
# 35         691          0           0     309000             0      1320
# 36         672          0           0     145000             0         0
# 37         498          0        1213     153000             0         0
# 38         246          0         731     109000             0         0
# 39           0          0           0      82000             0         0
# 40         440          0         643     160000             0         0
# 41         308          0         967     170000             0         0
# 42         504          0         747     144000             0         0
# 43         308          0         280     130250             0         0
# 44         300          0         179     141000             0         0
# 45         576          0         456     319900             0         0
# 46         670          0        1351     239686             0       631
# 47         826          0          24     249700             0         0
# 48           0          0           0     113000             0       716
# 49         386          0         763     127000             0         0
#
#     WoodDeckSF  BsmtFinSF2
# 0            0           0
# 1          298           0
# 2            0           0
# 3            0           0
# 4          192           0
# 5           40           0
# 6          255           0
# 7          235          32
# 8           90           0
# 9            0           0
# 10           0           0
# 11         147           0
# 12         140           0
# 13         160           0
# 14           0           0
# 15          48           0
# 16           0           0
# 17           0           0
# 18           0           0
# 19           0           0
# 20         240           0
# 21           0           0
# 22         171           0
# 23         100           0
# 24         406         668
# 25           0           0
# 26         222         486
# 27           0           0
# 28         288           0
# 29          49           0
# 30           0           0
# 31           0           0
# 32           0           0
# 33           0           0
# 34         203           0
# 35         113           0
# 36         392           0
# 37           0           0
# 38           0           0
# 39           0           0
# 40           0           0
# 41           0           0
# 42         240          93
# 43         145         491
# 44           0         506
# 45         196           0
# 46         168           0
# 47           0           0
# 48           0           0
# 49           0           0
#
# [50 rows x 21 columns]

# %%
train[date_var].isnull().sum()
# Out:
# YearRemodAdd     0
# YrSold           0
# GarageYrBlt     81
# MoSold           0
# YearBuilt        0
# dtype: int64

# %%
train[num_Categories].isnull().sum()
# Out:
# FullBath        0
# GarageCars      0
# BsmtHalfBath    0
# BsmtFullBath    0
# KitchenAbvGr    0
# Fireplaces      0
# TotRmsAbvGrd    0
# HalfBath        0
# BedroomAbvGr    0
# dtype: int64

# %%
train[object_var].isnull().sum()
# Out:
# MSZoning            0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType        872
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinType2       38
# Heating             0
# HeatingQC           0
# CentralAir          0
# Electrical          1
# KitchenQual         0
# Functional          0
# FireplaceQu       690
# GarageType         81
# GarageFinish       81
# GarageQual         81
# GarageCond         81
# PavedDrive          0
# PoolQC           1453
# Fence            1179
# MiscFeature      1406
# SaleType            0
# SaleCondition       0
# MSSubClass          0
# OverallQual         0
# OverallCond         0
# dtype: int64

# %% [markdown]
# Only LotFrontage had the missing value among numeric features and missing rows are dropped.

# %%
train = train.dropna( subset = numeric, ignore_index = True)
train[numeric].isnull().sum()
# Out:
# LotArea          0
# MiscVal          0
# BsmtUnfSF        0
# Id               0
# PoolArea         0
# LotFrontage      0
# OpenPorchSF      0
# ScreenPorch      0
# TotalBsmtSF      0
# GrLivArea        0
# MasVnrArea       0
# 1stFlrSF         0
# EnclosedPorch    0
# GarageArea       0
# 3SsnPorch        0
# BsmtFinSF1       0
# SalePrice        0
# LowQualFinSF     0
# 2ndFlrSF         0
# WoodDeckSF       0
# BsmtFinSF2       0
# dtype: int64

# %%
train[object_var].isnull().sum()
# Out:
# MSZoning            0
# Street              0
# Alley            1110
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType        728
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           31
# BsmtCond           31
# BsmtExposure       32
# BsmtFinType1       31
# BsmtFinType2       32
# Heating             0
# HeatingQC           0
# CentralAir          0
# Electrical          1
# KitchenQual         0
# Functional          0
# FireplaceQu       596
# GarageType         74
# GarageFinish       74
# GarageQual         74
# GarageCond         74
# PavedDrive          0
# PoolQC           1189
# Fence             967
# MiscFeature      1156
# SaleType            0
# SaleCondition       0
# MSSubClass          0
# OverallQual         0
# OverallCond         0
# dtype: int64

# %%
train = train.dropna(subset=['Electrical'], ignore_index = True)

# %%
train[num_Categories].isnull().sum()
# Out:
# FullBath        0
# GarageCars      0
# BsmtHalfBath    0
# BsmtFullBath    0
# KitchenAbvGr    0
# Fireplaces      0
# TotRmsAbvGrd    0
# HalfBath        0
# BedroomAbvGr    0
# dtype: int64

# %%
train[date_var].isnull().sum()
# Out:
# YearRemodAdd     0
# YrSold           0
# GarageYrBlt     74
# MoSold           0
# YearBuilt        0
# dtype: int64

# %%
train = train.dropna(subset=["GarageYrBlt"],ignore_index = True)
train[object_var].isnull().sum()
# Out:
# MSZoning            0
# Street              0
# Alley            1043
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType        659
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           24
# BsmtCond           24
# BsmtExposure       25
# BsmtFinType1       24
# BsmtFinType2       25
# Heating             0
# HeatingQC           0
# CentralAir          0
# Electrical          0
# KitchenQual         0
# Functional          0
# FireplaceQu       529
# GarageType          0
# GarageFinish        0
# GarageQual          0
# GarageCond          0
# PavedDrive          0
# PoolQC           1114
# Fence             905
# MiscFeature      1084
# SaleType            0
# SaleCondition       0
# MSSubClass          0
# OverallQual         0
# OverallCond         0
# dtype: int64

# %%
train.shape
# Out:
# (1120, 81)

# %%
train = train.fillna("None")
train.shape
# Out:
# (1120, 81)

# %%
train[object_var].head(50)
# Out:
#    MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0        RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 1        RL   Pave  None      Reg         Lvl    AllPub       FR2       Gtl
# 2        RL   Pave  None      IR1         Lvl    AllPub    Inside       Gtl
# 3        RL   Pave  None      IR1         Lvl    AllPub    Corner       Gtl
# 4        RL   Pave  None      IR1         Lvl    AllPub       FR2       Gtl
# 5        RL   Pave  None      IR1         Lvl    AllPub    Inside       Gtl
# 6        RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 7        RM   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 8        RL   Pave  None      Reg         Lvl    AllPub    Corner       Gtl
# 9        RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 10       RL   Pave  None      IR1         Lvl    AllPub    Inside       Gtl
# 11       RL   Pave  None      IR1         Lvl    AllPub    Inside       Gtl
# 12       RM   Pave  None      Reg         Lvl    AllPub    Corner       Gtl
# 13       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 14       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 15       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 16       RL   Pave  None      IR1         Lvl    AllPub    Corner       Gtl
# 17       RM   Pave  Grvl      Reg         Bnk    AllPub    Inside       Gtl
# 18       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 19       RM   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 20       RL   Pave  None      Reg         Lvl    AllPub    Corner       Gtl
# 21       RL   Pave  None      Reg         Lvl    AllPub    Corner       Gtl
# 22       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 23       RL   Pave  None      IR1         Lvl    AllPub   CulDSac       Gtl
# 24       RM   Pave  None      IR1         Lvl    AllPub    Inside       Gtl
# 25  C (all)   Pave  Pave      Reg         Lvl    AllPub    Inside       Gtl
# 26       RL   Pave  None      Reg         Lvl    AllPub    Corner       Gtl
# 27       RL   Pave  None      IR1         Lvl    AllPub    Inside       Gtl
# 28       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 29       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 30       RL   Pave  None      Reg         Lvl    AllPub    Corner       Gtl
# 31       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 32       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 33       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 34       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 35       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 36       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 37       RL   Pave  None      IR1         Lvl    AllPub   CulDSac       Gtl
# 38       FV   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 39       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 40       RM   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
# 41       RM   Grvl  None      IR2         Bnk    AllPub    Corner       Mod
# 42       RL   Pave  None      IR1         Low    AllPub    Inside       Gtl
# 43       RL   Pave  None      Reg         Bnk    AllPub    Inside       Mod
# 44       RL   Pave  None      IR1         Lvl    AllPub    Inside       Gtl
# 45       FV   Pave  Pave      Reg         Lvl    AllPub    Inside       Gtl
# 46       RL   Pave  None      IR1         Lvl    AllPub    Corner       Gtl
# 47       RL   Pave  None      IR2         HLS    AllPub   CulDSac       Gtl
# 48       RL   Pave  None      Reg         Bnk    AllPub    Inside       Gtl
# 49       RL   Pave  None      Reg         Lvl    AllPub    Inside       Gtl
#
#    Neighborhood Condition1  ... GarageCond PavedDrive PoolQC  Fence  \
# 0       CollgCr       Norm  ...         TA          Y   None   None
# 1       Veenker      Feedr  ...         TA          Y   None   None
# 2       CollgCr       Norm  ...         TA          Y   None   None
# 3       Crawfor       Norm  ...         TA          Y   None   None
# 4       NoRidge       Norm  ...         TA          Y   None   None
# 5       Mitchel       Norm  ...         TA          Y   None  MnPrv
# 6       Somerst       Norm  ...         TA          Y   None   None
# 7       OldTown     Artery  ...         TA          Y   None   None
# 8       BrkSide     Artery  ...         TA          Y   None   None
# 9        Sawyer       Norm  ...         TA          Y   None   None
# 10      NridgHt       Norm  ...         TA          Y   None   None
# 11      CollgCr       Norm  ...         TA          Y   None   None
# 12      BrkSide       Norm  ...         TA          Y   None  GdPrv
# 13       Sawyer       Norm  ...         TA          Y   None   None
# 14      SawyerW       RRAe  ...         TA          Y   None   None
# 15        NAmes       Norm  ...         TA          Y   None  MnPrv
# 16      NridgHt       Norm  ...         TA          Y   None   None
# 17       IDOTRR       Norm  ...         TA          N   None  GdPrv
# 18      CollgCr       Norm  ...         TA          Y   None   None
# 19      MeadowV       Norm  ...         TA          Y   None   None
# 20      NridgHt       Norm  ...         TA          Y   None   None
# 21        NAmes       Norm  ...         TA          Y   None   None
# 22      NridgHt       Norm  ...         TA          Y   None   None
# 23        NAmes       Norm  ...         TA          Y   None   None
# 24      BrkSide      Feedr  ...         TA          Y   None   None
# 25       IDOTRR      Feedr  ...         Fa          N   None  MnPrv
# 26      CollgCr       Norm  ...         TA          Y   None   None
# 27        NAmes       Norm  ...         TA          Y   None   None
# 28      NridgHt       Norm  ...         TA          Y   None   None
# 29      NridgHt       Norm  ...         TA          Y   None   None
# 30      CollgCr       Norm  ...         TA          Y   None   None
# 31        NAmes       Norm  ...         TA          Y   None   None
# 32        NAmes       Norm  ...         TA          Y   None   None
# 33        NAmes       Norm  ...         TA          Y   None   GdWo
# 34       Timber       Norm  ...         TA          P   None   None
# 35        NAmes       Norm  ...         TA          Y   None   None
# 36      NridgHt       Norm  ...         TA          Y   None   None
# 37      Mitchel       Norm  ...         TA          Y   None   None
# 38      Somerst       Norm  ...         TA          Y   None   None
# 39       Sawyer       Norm  ...         TA          Y   None  MnPrv
# 40      BrkSide       Norm  ...         TA          Y   None  MnPrv
# 41       IDOTRR       RRNn  ...         TA          Y   None   None
# 42      Veenker       Norm  ...         TA          Y   None   None
# 43        NAmes       Norm  ...         TA          Y   None  MnPrv
# 44        NAmes       Norm  ...         TA          Y   None   None
# 45      Somerst       Norm  ...         TA          Y   None   None
# 46      CollgCr       Norm  ...         TA          Y   None   None
# 47      StoneBr       Norm  ...         TA          Y   None   None
# 48      CollgCr       Norm  ...         TA          Y   None  MnPrv
# 49      SawyerW       RRAe  ...         TA          Y   None   None
#
#    MiscFeature SaleType SaleCondition MSSubClass OverallQual OverallCond
# 0         None       WD        Normal         60           7           5
# 1         None       WD        Normal         20           6           8
# 2         None       WD        Normal         60           7           5
# 3         None       WD       Abnorml         70           7           5
# 4         None       WD        Normal         60           8           5
# 5         Shed       WD        Normal         50           5           5
# 6         None       WD        Normal         20           8           5
# 7         None       WD       Abnorml         50           7           5
# 8         None       WD        Normal        190           5           6
# 9         None       WD        Normal         20           5           5
# 10        None      New       Partial         60           9           5
# 11        None      New       Partial         20           7           5
# 12        None       WD        Normal         45           7           8
# 13        Shed       WD        Normal         90           4           5
# 14        None       WD        Normal         20           5           5
# 15        None      COD       Abnorml         20           5           6
# 16        None      New       Partial         60           8           5
# 17        None       WD        Normal         45           7           7
# 18        None       WD        Normal         20           8           5
# 19        None       WD        Normal        120           5           7
# 20        None       WD        Normal         20           8           5
# 21        None       WD        Normal         20           5           7
# 22        None       WD        Normal         20           8           5
# 23        None       WD        Normal         20           5           6
# 24        None       WD        Normal         30           4           6
# 25        None       WD        Normal         70           4           4
# 26        None       WD        Normal         20           8           5
# 27        None       WD        Normal         20           5           5
# 28        None       WD        Normal        120           9           5
# 29        None       WD        Normal         60           8           5
# 30        None       WD        Normal         20           5           5
# 31        None       WD        Normal         20           5           6
# 32        None       WD       Abnorml         20           5           7
# 33        None       WD       Abnorml         20           6           5
# 34        None       WD        Normal         20           5           6
# 35        None       WD        Normal         20           5           6
# 36        None       WD        Normal        120           9           5
# 37        None       WD       Abnorml         50           7           5
# 38        None       WD        Normal         20           8           5
# 39        None       WD        Normal         20           5           7
# 40        Shed       WD        Normal         50           6           6
# 41        None       WD        Normal         90           5           5
# 42        None       WD        Normal         20           9           5
# 43        None       WD        Normal         80           5           5
# 44        None       WD        Normal         20           6           5
# 45        None       WD       Abnorml        160           8           5
# 46        None       WD        Normal         60           7           5
# 47        None      New       Partial         60          10           5
# 48        None       WD        Normal         20           5           7
# 49        None      New       Partial         20           6           5
#
# [50 rows x 46 columns]

# %% [markdown]
# Electrical's missing value was removed along with the missing values from GarageYrBuilt which removed row for missing value of garage related features too.

# %% [markdown]
# Other Categorical features had None option as NA so all of the other missing values were filled with "None".

# %% [markdown]
# ## Handling Categorical Attributes

# %%
num_Categories
# Out:
# ['FullBath',
#  'GarageCars',
#  'BsmtHalfBath',
#  'BsmtFullBath',
#  'KitchenAbvGr',
#  'Fireplaces',
#  'TotRmsAbvGrd',
#  'HalfBath',
#  'BedroomAbvGr']

# %%
object_var
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition',
#  'MSSubClass',
#  'OverallQual',
#  'OverallCond']

# %%
train[object_var].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1120 entries, 0 to 1119
# Data columns (total 46 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSZoning       1120 non-null   object
#  1   Street         1120 non-null   object
#  2   Alley          1120 non-null   object
#  3   LotShape       1120 non-null   object
#  4   LandContour    1120 non-null   object
#  5   Utilities      1120 non-null   object
#  6   LotConfig      1120 non-null   object
#  7   LandSlope      1120 non-null   object
#  8   Neighborhood   1120 non-null   object
#  9   Condition1     1120 non-null   object
#  10  Condition2     1120 non-null   object
#  11  BldgType       1120 non-null   object
#  12  HouseStyle     1120 non-null   object
#  13  RoofStyle      1120 non-null   object
#  14  RoofMatl       1120 non-null   object
#  15  Exterior1st    1120 non-null   object
#  16  Exterior2nd    1120 non-null   object
#  17  MasVnrType     1120 non-null   object
#  18  ExterQual      1120 non-null   object
#  19  ExterCond      1120 non-null   object
#  20  Foundation     1120 non-null   object
#  21  BsmtQual       1120 non-null   object
#  22  BsmtCond       1120 non-null   object
#  23  BsmtExposure   1120 non-null   object
#  24  BsmtFinType1   1120 non-null   object
#  25  BsmtFinType2   1120 non-null   object
#  26  Heating        1120 non-null   object
#  27  HeatingQC      1120 non-null   object
#  28  CentralAir     1120 non-null   object
#  29  Electrical     1120 non-null   object
#  30  KitchenQual    1120 non-null   object
#  31  Functional     1120 non-null   object
#  32  FireplaceQu    1120 non-null   object
#  33  GarageType     1120 non-null   object
#  34  GarageFinish   1120 non-null   object
#  35  GarageQual     1120 non-null   object
#  36  GarageCond     1120 non-null   object
#  37  PavedDrive     1120 non-null   object
#  38  PoolQC         1120 non-null   object
#  39  Fence          1120 non-null   object
#  40  MiscFeature    1120 non-null   object
#  41  SaleType       1120 non-null   object
#  42  SaleCondition  1120 non-null   object
#  43  MSSubClass     1120 non-null   int64
#  44  OverallQual    1120 non-null   int64
#  45  OverallCond    1120 non-null   int64
# dtypes: int64(3), object(43)
# memory usage: 402.6+ KB

# %%
rating_2 = {"None", "Unf", "LwQ", "Rec", "BLQ", "ALQ", "GLQ"}
rating_3 = {"None","Po","Fa","TA","Gd","Ex"}
rating_1 = { "None", "No", "Mn", "Av", "Gd"}

for i in object_var:
    categories = set(train[i].value_counts().index.tolist())
    if (categories.issubset(rating_1) or categories.issubset(rating_2) or categories.issubset(rating_3)):
        print(i)
        num_Categories.append(i)
# Out:
# ExterQual
# ExterCond
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinType2
# HeatingQC
# KitchenQual
# FireplaceQu
# GarageQual
# GarageCond
# PoolQC

# %%
num_Categories
# Out:
# ['FullBath',
#  'GarageCars',
#  'BsmtHalfBath',
#  'BsmtFullBath',
#  'KitchenAbvGr',
#  'Fireplaces',
#  'TotRmsAbvGrd',
#  'HalfBath',
#  'BedroomAbvGr',
#  'ExterQual',
#  'ExterCond',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'HeatingQC',
#  'KitchenQual',
#  'FireplaceQu',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC']

# %%
num_Categories = list(set(num_Categories))

# %%
num_Categories
# Out:
# ['GarageQual',
#  'BsmtExposure',
#  'BsmtFinType2',
#  'KitchenQual',
#  'FireplaceQu',
#  'BsmtQual',
#  'Fireplaces',
#  'GarageCars',
#  'BsmtHalfBath',
#  'BsmtFullBath',
#  'GarageCond',
#  'BedroomAbvGr',
#  'FullBath',
#  'ExterCond',
#  'HalfBath',
#  'ExterQual',
#  'PoolQC',
#  'BsmtFinType1',
#  'HeatingQC',
#  'BsmtCond',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd']

# %%
num_Categories.append("OverallCond")
num_Categories.append("OverallQual")

object_var = list(set(object_var) - set(num_Categories))
object_var
# Out:
# ['Alley',
#  'LotShape',
#  'Exterior1st',
#  'LotConfig',
#  'Foundation',
#  'HouseStyle',
#  'Electrical',
#  'LandSlope',
#  'MasVnrType',
#  'Heating',
#  'BldgType',
#  'GarageFinish',
#  'MiscFeature',
#  'Street',
#  'Functional',
#  'RoofStyle',
#  'Exterior2nd',
#  'LandContour',
#  'MSSubClass',
#  'Utilities',
#  'CentralAir',
#  'Condition1',
#  'Condition2',
#  'Neighborhood',
#  'GarageType',
#  'PavedDrive',
#  'MSZoning',
#  'RoofMatl',
#  'SaleCondition',
#  'Fence',
#  'SaleType']

# %% [markdown]
# The object variable are now seperated. On one end, we have rating which correlate with each other and we can use ordinal encoding on them.

# %% [markdown]
# ### Ordinal Encoding for relative categories

# %%
train[num_Categories].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1120 entries, 0 to 1119
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   GarageQual    1120 non-null   object
#  1   BsmtExposure  1120 non-null   object
#  2   BsmtFinType2  1120 non-null   object
#  3   KitchenQual   1120 non-null   object
#  4   FireplaceQu   1120 non-null   object
#  5   BsmtQual      1120 non-null   object
#  6   Fireplaces    1120 non-null   int64
#  7   GarageCars    1120 non-null   int64
#  8   BsmtHalfBath  1120 non-null   int64
#  9   BsmtFullBath  1120 non-null   int64
#  10  GarageCond    1120 non-null   object
#  11  BedroomAbvGr  1120 non-null   int64
#  12  FullBath      1120 non-null   int64
#  13  ExterCond     1120 non-null   object
#  14  HalfBath      1120 non-null   int64
#  15  ExterQual     1120 non-null   object
#  16  PoolQC        1120 non-null   object
#  17  BsmtFinType1  1120 non-null   object
#  18  HeatingQC     1120 non-null   object
#  19  BsmtCond      1120 non-null   object
#  20  KitchenAbvGr  1120 non-null   int64
#  21  TotRmsAbvGrd  1120 non-null   int64
#  22  OverallCond   1120 non-null   int64
#  23  OverallQual   1120 non-null   int64
# dtypes: int64(11), object(13)
# memory usage: 210.1+ KB

# %%
ordinal_categories = [ var for var in train[num_Categories].columns if train[var].dtype == "O"]
ordinal_categories
# Out:
# ['GarageQual',
#  'BsmtExposure',
#  'BsmtFinType2',
#  'KitchenQual',
#  'FireplaceQu',
#  'BsmtQual',
#  'GarageCond',
#  'ExterCond',
#  'ExterQual',
#  'PoolQC',
#  'BsmtFinType1',
#  'HeatingQC',
#  'BsmtCond']

# %%
train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
rating_1 = ["None", "No", "Mn", "Av", "Gd"]
rating_2 = ["None", "Unf", "LwQ", "Rec", "BLQ", "ALQ", "GLQ"]
rating_3 = ["None","Po","Fa","TA","Gd","Ex"]

rating_3_cat = list()
rating_2_cat = list()
rating_1_cat = list()

for i in categorical:
    if set(train[i].value_counts().index.tolist()).issubset(set(rating_3)):
        print(i)
        rating_3_cat.append(i)

for i in categorical:
    if set(train[i].value_counts().index.tolist()).issubset(set(rating_2)):
        print(i)
        rating_2_cat.append(i)

for i in categorical:
    if set(train[i].value_counts().index.tolist()).issubset(set(rating_1)):
        print(i)
        rating_1_cat.append(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 9
#       6 rating_2_cat = list()
#       7 rating_1_cat = list()
# ----> 9 for i in categorical:
#      10     if set(train[i].value_counts().index.tolist()).issubset(set(rating_3)):
#      11         print(i)
#
# NameError: name 'categorical' is not defined

# %%
rating_1_encoder = OrdinalEncoder(categories = [[rating_1] * len(rating_1_cat)])
rating_2_encoder = OrdinalEncoder(categories = [[rating_2] * len(rating_2_cat)])
rating_3_encoder = OrdinalEncoder(categories = [[rating_3] * len(rating_3_cat)])

# %%
ordinal_encoder = ColumnTransformer([
    ("rating1", rating_1_encoder, rating_1_cat),
    ("rating2", rating_2_encoder, rating_2_cat),
    ("rating3", rating_3_encoder, rating_3_cat)
],remainder = "passthrough")
ordinal_encoder.fit(train)
train_encoded = ordinal_encoder.transform(train)
train_encoded
columns = ordinal_encoder.get_feature_names_out()
train_encoded_df = pd.DataFrame(train_encoded, columns = columns)
train_encoded_df

# %%
train

# %% [markdown]
# Ordinal Categories are all processed.

# %% [markdown]
# ### Text Attributes

# %%
object_var

# %%
train[object_var].info()

# %%
train['MSSubClass'] = train['MSSubClass'].astype('string')

# %%
from sklearn.preprocessing import OneHotEncoder

hot_cat = train[object_var]
one_hot_encoder = OneHotEncoder().fit(hot_cat)
one_hot_encoder

# %%
one_hot_df = pd.DataFrame(one_hot_encoder.transform(hot_cat), columns = one_hot_encoder.get_feature_names_out())
one_hot_df

# %% [markdown]
# Need to figure out,
# - how to incorporate the output of these transformation while training and for further testing of data too.

# %% [markdown]
# ## Handling Numerical Attributes

# %%
numeric

# %%
train[numeric].head(20)

# %%
train[numeric].describe()

# %%
train[numeric[:8]].hist(bins=50,figsize=(12,8))
plt.show()

# %%
train[numeric[8:16]].hist(bins=50,figsize=(12,8))
plt.show()

# %%
train["3SsnPorch"].value_counts()

# %%
train[numeric[16:20]].hist(bins=50,figsize=(12,8))
plt.show()

# %%
numeric.remove('Id')
numeric

# %%
# train[numeric] = np.log(train[numeric] + 1)
# train[numeric].head(50)

# %%
train[numeric[:10]].hist(bins=50, figsize=(12,10))
plt.show()

# %%
train[numeric[10:21]].hist(bins=50, figsize=(12,10))
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

minmax = MinMaxScaler()
numeric_scaled = minmax.fit_transform(train[numeric])
numeric_scaled

# %%
type(numeric_scaled)

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class DataFrameTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, columns=None):
        self.columns = columns

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        if isinstance(X, pd.DataFrame):
            return X
        return pd.DataFrame(X, columns=self.columns)

# %%
df_transformer = DataFrameTransformer(columns = numeric)
numeric_df = df_transformer.transform(numeric_scaled)
numeric_df

# %% [markdown]
# ## Handling Date variables

# %%
date_var

# %%
train[date_var].head(20)

# %%
train['GarageYrBlt'] = train['GarageYrBlt'].astype("int64")

# %% [markdown]
# ## Building Pipeline

# %%
numeric = numeric.remove("SalePrice")

# %%
from sklearn.preprocessing import FunctionTransformer

def log_transformer(x):
    return np.log(x + 1)

log_transformer = FunctionTransformer(func = log_transformer, inverse_func = np.exp)





def ordinal_encoder(X):
    rating_2 = ["None", "Unf", "LwQ", "Rec", "BLQ", "ALQ", "GLQ"]
    rating_3 = ["None","Po","Fa","TA","Gd","Ex"]
    rating_1 = ["None", "No", "Mn", "Av", "Gd"]
    
    rating_3_cat = list()
    rating_2_cat = list()
    rating_1_cat = list()
    
    for i in X.columns:
        if set(train[i].value_counts().index.tolist()).issubset(set(rating_3)):
            print(i)
            rating_3_cat.append(i)
    
    for i in X.columns:
        if set(train[i].value_counts().index.tolist()).issubset(set(rating_2)):
            print(i)
            rating_2_cat.append(i)
    
    for i in X.columns:
        if set(train[i].value_counts().index.tolist()).issubset(set(rating_1)):
            print(i)
            rating_1_cat.append(i)
    
    rating_3_encoder = OrdinalEncoder(categories = [rating_3 * len(rating_3_cat) ] )
    rating_2_encoder = OrdinalEncoder(categories = [rating_2 * len(rating_2_cat) ] )
    rating_1_encoder = OrdinalEncoder(categories = [rating_1 * len(rating_1_cat) ] )

    ordinal_encoder_transformer = ColumnTransformer(
        [("rating_1", rating_1_encoder, rating_1_cat),
         ("rating_2", rating_2_encoder, rating_2_cat),
         ("rating_3", rating_3_encoder, rating_3_cat)]
    )
    return ordinal_encoder_transformer.fit_transform(X)

ordinal_transformer = FunctionTransformer( ordinal_encoder, validate=False)

# %%
# def handle_date(X):
#     column = X.columns
#     for i in column:
#         if X[i].dtype == "float64" or X[i].dtype == "O":
#             X[i] = X[i].astype("int64")
#     return X

# date_conversion = FunctionTransformer( handle_date, validate=True)

# %%
from sklearn.pipeline import Pipeline

num_pipeline = Pipeline([
    ("log_transformer", log_transformer),
    ("MinmaxScaler", MinMaxScaler())    
])

ordinal_cat_pipeline = Pipeline([
    ("ordinal_transformer", ordinal_transformer)
])

text_cat_pipeline = Pipeline([
    ("one_hot_encoder", OneHotEncoder())
])

# date_pipeline = Pipeline ([
#     ("type_conversion", date_conversion)
# ])

# %%
preprocessing = ColumnTransformer([
    ("numeric", num_pipeline, numeric),
    ("ordinal", ordinal_cat_pipeline, ordinal_categories),
    ("onehot", text_cat_pipeline, object_var)
])

train

# %%
X_train = train.drop(columns = {"SalePrice"})
y_train = train["SalePrice"]
print(X_train)
print(y_train)

# %%
final_train = preprocessing.fit_transform(X_train)
final_train

# %% [markdown]
# ## Test data exploration

# %%
test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence  \
# 0            Lvl    AllPub  ...         120        0    NaN  MnPrv
# 1            Lvl    AllPub  ...           0        0    NaN    NaN
# 2            Lvl    AllPub  ...           0        0    NaN  MnPrv
# 3            Lvl    AllPub  ...           0        0    NaN    NaN
# 4            HLS    AllPub  ...         144        0    NaN    NaN
# ...          ...       ...  ...         ...      ...    ...    ...
# 1454         Lvl    AllPub  ...           0        0    NaN    NaN
# 1455         Lvl    AllPub  ...           0        0    NaN    NaN
# 1456         Lvl    AllPub  ...           0        0    NaN    NaN
# 1457         Lvl    AllPub  ...           0        0    NaN  MnPrv
# 1458         Lvl    AllPub  ...           0        0    NaN    NaN
#
#      MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0            NaN       0      6    2010        WD         Normal
# 1           Gar2   12500      6    2010        WD         Normal
# 2            NaN       0      3    2010        WD         Normal
# 3            NaN       0      6    2010        WD         Normal
# 4            NaN       0      1    2010        WD         Normal
# ...          ...     ...    ...     ...       ...            ...
# 1454         NaN       0      6    2006        WD         Normal
# 1455         NaN       0      4    2006        WD        Abnorml
# 1456         NaN       0      9    2006        WD        Abnorml
# 1457        Shed     700      7    2006        WD         Normal
# 1458         NaN       0     11    2006        WD         Normal
#
# [1459 rows x 80 columns]

# %%
test.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           4
# LotFrontage      227
# LotArea            0
#                 ...
# MiscVal            0
# MoSold             0
# YrSold             0
# SaleType           1
# SaleCondition      0
# Length: 80, dtype: int64

# %%
numeric = list(set(numeric) - {"SalePrice"})
test[numeric].isnull().sum()
# Out:
# LotArea            0
# GarageArea         1
# 3SsnPorch          0
# BsmtFinSF1         1
# MiscVal            0
# BsmtUnfSF          1
# Id                 0
# PoolArea           0
# LotFrontage      227
# OpenPorchSF        0
# LowQualFinSF       0
# ScreenPorch        0
# TotalBsmtSF        1
# GrLivArea          0
# MasVnrArea        15
# 2ndFlrSF           0
# 1stFlrSF           0
# EnclosedPorch      0
# WoodDeckSF         0
# BsmtFinSF2         1
# dtype: int64

# %%
test[object_var].isnull().sum()
# Out:
# Alley            1352
# LotShape            0
# Exterior1st         1
# LotConfig           0
# Foundation          0
# HouseStyle          0
# Electrical          0
# LandSlope           0
# MasVnrType        894
# Heating             0
# BldgType            0
# GarageFinish       78
# MiscFeature      1408
# Street              0
# Functional          2
# RoofStyle           0
# Exterior2nd         1
# LandContour         0
# MSSubClass          0
# Utilities           2
# CentralAir          0
# Condition1          0
# Condition2          0
# Neighborhood        0
# GarageType         76
# PavedDrive          0
# MSZoning            4
# RoofMatl            0
# SaleCondition       0
# Fence            1169
# SaleType            1
# dtype: int64

# %%
test[num_Categories].isnull().sum()
# Out:
# GarageQual        78
# BsmtExposure      44
# BsmtFinType2      42
# KitchenQual        1
# FireplaceQu      730
# BsmtQual          44
# Fireplaces         0
# GarageCars         1
# BsmtHalfBath       2
# BsmtFullBath       2
# GarageCond        78
# BedroomAbvGr       0
# FullBath           0
# ExterCond          0
# HalfBath           0
# ExterQual          0
# PoolQC          1456
# BsmtFinType1      42
# HeatingQC          0
# BsmtCond          45
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# OverallCond        0
# OverallQual        0
# dtype: int64

# %%
test[date_var].isnull().sum()
# Out:
# YearRemodAdd     0
# YrSold           0
# GarageYrBlt     78
# MoSold           0
# YearBuilt        0
# dtype: int64

# %%
test.shape
# Out:
# (1459, 80)
